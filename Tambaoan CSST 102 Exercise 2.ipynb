# %% [markdown]
# 1. Student Data Frame

# %%
students <- data.frame(
  StudentId = c("S001", "S002", "S003", "S004", "S005"),
  Attendance = c(95, 72, 88, 79, 68),
  Grade = c(90, 70, 85, 77, 65),
  Risk = c("Low Risk", "High Risk", "Low Risk", "Moderate Risk", "High Risk")
)

print(students)
# Out:
#   StudentId Attendance Grade          Risk
# 1      S001         95    90      Low Risk
# 2      S002         72    70     High Risk
# 3      S003         88    85      Low Risk
# 4      S004         79    77 Moderate Risk
# 5      S005         68    65     High Risk

# %% [markdown]
# 2. Create Variables

# %%
attendance_rate <- 82

average_grade <- 78

print(attendance_rate)

print(average_grade)
# Out:
# [1] 82
# [1] 78

# %% [markdown]
# 3. Basic Calculations

# %%
quiz <- 85
lab <- 90
project <- 88
exam <- 80

final_grade <- (quiz * 0.20) + (lab * 0.25) + (project * 0.25) + (exam * 0.30)
print(final_grade)
# Out:
# [1] 85.5

# %% [markdown]
# 4. Using Comparison Operators

# %%
attendance <- 72
grade <- 70

attbelow75 <- attendance < 75
gradebelow75 <- grade < 75
attisatleast <- attendance <= 75
gradeisatleast <- grade <= 75

print(attbelow75)
print(gradebelow75)
print(attisatleast)
print(gradeisatleast)
# Out:
# [1] TRUE
# [1] TRUE
# [1] TRUE
# [1] TRUE

# %% [markdown]
# 5. Using AND & OR

# %%
attendance <- 72
grade <- 70

if (attendance < 75 && grade < 75) {
  print("Student is at risk")
} else {
  print("Student is not at risk")
}
# Out:
# [1] "Student is at risk"

# %% [markdown]
# 6. Simple IF Statement

# %%
grade <- 80

if (grade < 75) {
  print("Passed")
} else {
  print("Failed")
}
# Out:
# [1] "Failed"

# %% [markdown]
# 7. Multiple Conditions

# %%
grade <- 90

if (grade >= 90){
  print("Excellent")
}else if (grade >= 85){
  print("Very Good")
}else if (grade >= 80){
  print("Good")
}else if (grade >= 75){
  print("Passed")
}else {
  print("Failed")
}
# Out:
# [1] "Excellent"

# %% [markdown]
# 8. Creating Function

# %%
classify_grade <- function(grade) {



  if (grade >= 90){
  print("Excellent")
}else if (grade >= 85){
  print("Very Good")
}else if (grade >= 80){
  print("Good")
}else if (grade >= 75){
  print("Passed")
}else {
  print("Failed")
}

}
grade <- 80
classify_grade(grade)
# Out:
# [1] "Good"

# %% [markdown]
# 9. Creating a Data Frame

# %%
students <- data.frame(
  StudentId = c("S001", "S002", "S003", "S004", "S005"),
  Attendance = c(95, 72, 88, 79, 68),
  Grade = c(90, 70, 85, 77, 65)
)

print(students)
# Out:
#   StudentId Attendance Grade
# 1      S001         95    90
# 2      S002         72    70
# 3      S003         88    85
# 4      S004         79    77
# 5      S005         68    65

# %% [markdown]
# 10. Adding a Classification Collumn

# %%
students$Performance <- ifelse(
  students$Grade >= 80,
  "Good",
  ifelse(
    students$Grade >= 75,
    "Passed", "Failed"
  )
)
students
# Out:
#   StudentId Attendance Grade Performance
# 1 S001      95         90    Good
# 2 S002      72         70    Failed
# 3 S003      88         85    Good
# 4 S004      79         77    Passed
# 5 S005      68         65    Failed

# %% [markdown]
# 11. Creating a Simple Rule Based System

# %%
classify_grade <- function(attendance, grade) {

  if (attendance < 75 && grade < 75) {
    print("High Risk")

  } else if (attendance < 85 || grade < 80) {
    print("Moderate Risk")

  } else {
    print("Low Risk")
  }
}

# %% [markdown]
# 12. Add More Rules

# %%
student_id <- "S001"
attendance <- 72
grade <- 70
# Out:
# [1] "Low Risk"
# [1] "High Risk"
# [1] "Low Risk"
# [1] "Moderate Risk"
# [1] "High Risk"
#   StudentId Attendance Grade Performance Risk
# 1 S001      95         90    Good        Low Risk
# 2 S002      72         70    Failed      High Risk
# 3 S003      88         85    Good        Low Risk
# 4 S004      79         77    Passed      Moderate Risk
# 5 S005      68         65    Failed      High Risk

# %% [markdown]
#   13. Apply the rule to Multiple Student

# %%
classify_grade <- function(attendance, grade) {

  if (attendance < 75 && grade < 75) {
    return("High Risk")

  } else if (attendance < 85 || grade < 80) {
    return("Moderate Risk")

  } else {
    return("Low Risk")
  }
}

students$Risk <- mapply(
  classify_grade,
  students$Attendance,
  students$Grade
)

students
# Out:
#   StudentId Attendance Grade Performance Risk
# 1 S001      95         90    Good        Low Risk
# 2 S002      72         70    Failed      High Risk
# 3 S003      88         85    Good        Low Risk
# 4 S004      79         77    Passed      Moderate Risk
# 5 S005      68         65    Failed      High Risk

# %% [markdown]
# 14. Count the Result

# %% [markdown]
# 1. How many student are High Risk?
# 2. How many are Moderate Risk?
# 3. How many are Low Risk
# 4. Which group has the largest number of students

# %%
table(students$Risk)
# Out:
#     High Risk      Low Risk Moderate Risk
#             2             2             1

# %% [markdown]
# 15. Create **Visualization**

# %%
risk_counts <- table(students$Risk)

barplot(
  risk_counts,
  main = "Student Risk Classification",
  xlab = "Risk Level",
  ylab = "Number of Students"
)
# Out:
# Plot with title “Student Risk Classification”

# %% [markdown]
# 16
# Add a Recommendation

# %%
recommendation <- function(risk) {

  if (risk == "High Risk") {
    return("Immediate academic intervention")

  } else if (risk == "Moderate Risk") {
    return("Academic monitoring")

  } else {
    return("Continue regular monitoring")
  }
}

students
# Out:
#   StudentId Attendance Grade Performance Risk
# 1 S001      95         90    Good        Low Risk
# 2 S002      72         70    Failed      High Risk
# 3 S003      88         85    Good        Low Risk
# 4 S004      79         77    Passed      Moderate Risk
# 5 S005      68         65    Failed      High Risk
#   Recommendation
# 1 Continue regular monitoring
# 2 Immediate academic intervention
# 3 Continue regular monitoring
# 4 Academic monitoring
# 5 Immediate academic intervention

# %% [markdown]
# 17. Mini KRR System

# %%
classify_grade <- function(attendance, grade) {
  if (attendance < 75 && grade < 75) {
    return("High Risk")
  } else if (attendance < 85 || grade < 80) {
    return("Moderate Risk")
  } else {
    return("Low Risk")
  }
}

recommendation <- function(risk) {
  if (risk == "High Risk") {
    return("Immediate academic intervention")
  } else if (risk == "Moderate Risk") {
    return("Academic monitoring")
  } else {
    return("Continue regular monitoring")
  }
}

StudentId <- "S001"
Attendance <- 85
Grade <- 72

result <- data.frame(
  StudentId,
  Attendance,
  Grade,
  Risk,
  Recommendation
)

print(result)
# Out:
#   StudentId Attendance Grade          Risk      Recommendation
# 1      S001         85    72 Moderate Risk Academic monitoring
